# %%
from config import PROJ_ROOT
import sys

# %%
sys.path.insert(0, str(PROJ_ROOT))

# %%
from src.config.smard import filter_dict

# %%
import pandas as pd
import requests
import re
import sys
from config import PROJ_ROOT

#change to base directory to import data dictionary from the references folder
sys.path.insert(0, str(PROJ_ROOT))
from src.config.smard import filter_dict
