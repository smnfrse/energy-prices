# %%
import pandas as pd
from src.modeling.baselines import calculate_baselines
from src.modeling.baselines import save_baseline_from_mlflow
# Out:
# 2026-02-24 10:20:50.617 | INFO     | src.config:<module>:12 - PROJ_ROOT path is: C:\Users\admin\Documents\1WBS\energy_prices

# %% [markdown]
# ### Calculate cheaper baselines

# %%
calculate_baselines(test_size=0.2, 
                    transformations=["none", "log_shift", "yeo_johnson", "quantile"]
                    )
# Out:
# 2026/02/24 10:20:56 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2026/02/24 10:20:56 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2026-02-24 10:20:56.773 | INFO     | src.modeling.baselines:calculate_baselines:249 - Loading data from C:\Users\admin\Documents\1WBS\energy_prices\data\processed\features_hourly.parquet
# 2026-02-24 10:20:57.032 | INFO     | src.modeling.baselines:calculate_baselines:253 - Loaded 97440 hourly observations
# 2026-02-24 10:20:57.033 | INFO     | src.modeling.baselines:calculate_baselines:261 - Split: 77952 train hours, 812 test days (19488 hours)
# 2026-02-24 10:20:57.034 | INFO     | src.modeling.baselines:calculate_baselines:295 - Running naive_daily_none...
# 2026-02-24 10:20:57.475 | INFO     | src.modeling.baselines:calculate_baselines:351 -   naive_daily_none: RMSE=41.53, MAE=26.44, R²=0.365
# 2026-02-24 10:20:57.476 | INFO     | src.modeling.baselines:calculate_baselines:295 - Running naive_daily_log_shift...
# ...

# %%
save_baseline_from_mlflow('5d51565300854e64a318b16ce9128694')

# %% [markdown]
# ### Hourly baseline

# %%
from src.modeling.baselines import get_default_baseline_predictions
baselines = get_default_baseline_predictions(hourly=True)
